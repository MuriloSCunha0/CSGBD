# %%
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interact
import pandas as pd
import psycopg2 as pg
import sqlalchemy
from sqlalchemy import create_engine
import datetime
import sqlite3 as sql
import os

# %% [markdown]
# ### Conexão com o banco de dados

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
sqlalchemy.create_engine(cnx)
# Out:
# Engine(postgresql://postgres:***@localhost/Projeto)

# %%
con = pg.connect(host='localhost', dbname= 'postgres', user='postgres', password= 'abacadaba12')

# %%
#%reload_ext sql

cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
#engine = sqlalchemy.create_engine(cnx)


#os.environ["DB_HOST"] = "localhost"
#os.environ["DB_PORT"] = "5432"
#os.environ["DB_NAME"] = "Projeto"
#os.environ["DB_USER"] = "paugu"
#os.environ["DB_PASSWORD"] = "abacadaba12"

#conn = pg.connect(
#    host=os.environ["DB_HOST"],
#    port=os.environ["DB_PORT"],
#    dbname=os.environ["DB_NAME"],
#    user=os.environ["DB_USER"],
#    password=os.environ["DB_PASSWORD"]
#)

#"SELECT COUNT(*) AS quantidade_de_tabelas FROM information_schema.tables WHERE table_schema = 'perfil'"
df = pd.read_sql_query("SELECT COUNT(*) AS quantidade_de_tabelas FROM information_schema.tables WHERE table_schema = 'perfil'", con=cnx)
df


#%sql $engine.url
#%sql SELECT * FROM perfil.perfil_filiado WHERE sg_partido = 'UP'
#con = pg.connect(host='localhost', dbname= 'postgres', user='postgres', password= 'abacadaba12')

#query = 'SELECT * FROM perfil.perfil_filiado' 
#new_df = pd.read_sql(query, engine)
#new_df.head(3)
# Out:
#    quantidade_de_tabelas
# 0                      1

# %%
#%reload_ext sql

cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
#engine = sqlalchemy.create_engine(cnx)


#os.environ["DB_HOST"] = "localhost"
#os.environ["DB_PORT"] = "5432"
#os.environ["DB_NAME"] = "Projeto"
#os.environ["DB_USER"] = "paugu"
#os.environ["DB_PASSWORD"] = "abacadaba12"

#conn = pg.connect(
#    host=os.environ["DB_HOST"],
#    port=os.environ["DB_PORT"],
#    dbname=os.environ["DB_NAME"],
#    user=os.environ["DB_USER"],
#    password=os.environ["DB_PASSWORD"]
#)

#"SELECT COUNT(*) AS quantidade_de_tabelas FROM information_schema.tables WHERE table_schema = 'perfil'"
df = pd.read_sql_query("SELECT COUNT(*) AS quantidade_de_tabelas FROM information_schema.tables WHERE table_schema = 'delegados'", con=cnx)
df


#%sql $engine.url
#%sql SELECT * FROM perfil.perfil_filiado WHERE sg_partido = 'UP'
#con = pg.connect(host='localhost', dbname= 'postgres', user='postgres', password= 'abacadaba12')

#query = 'SELECT * FROM perfil.perfil_filiado' 
#new_df = pd.read_sql(query, engine)
#new_df.head(3)
# Out:
#    quantidade_de_tabelas
# 0                     37

# %%
#%reload_ext sql

cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
#engine = sqlalchemy.create_engine(cnx)


#os.environ["DB_HOST"] = "localhost"
#os.environ["DB_PORT"] = "5432"
#os.environ["DB_NAME"] = "Projeto"
#os.environ["DB_USER"] = "paugu"
#os.environ["DB_PASSWORD"] = "abacadaba12"

#conn = pg.connect(
#    host=os.environ["DB_HOST"],
#    port=os.environ["DB_PORT"],
#    dbname=os.environ["DB_NAME"],
#    user=os.environ["DB_USER"],
#    password=os.environ["DB_PASSWORD"]
#)

#"SELECT COUNT(*) AS quantidade_de_tabelas FROM information_schema.tables WHERE table_schema = 'perfil'"
df = pd.read_sql_query("SELECT COUNT(*) AS quantidade_de_tabelas FROM information_schema.tables WHERE table_schema = 'orgaos'", con=cnx)
df


#%sql $engine.url
#%sql SELECT * FROM perfil.perfil_filiado WHERE sg_partido = 'UP'
#con = pg.connect(host='localhost', dbname= 'postgres', user='postgres', password= 'abacadaba12')

#query = 'SELECT * FROM perfil.perfil_filiado' 
#new_df = pd.read_sql(query, engine)
#new_df.head(3)
# Out:
#    quantidade_de_tabelas
# 0                     37

# %%
#%reload_ext sql

cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
#engine = sqlalchemy.create_engine(cnx)


#os.environ["DB_HOST"] = "localhost"
#os.environ["DB_PORT"] = "5432"
#os.environ["DB_NAME"] = "Projeto"
#os.environ["DB_USER"] = "paugu"
#os.environ["DB_PASSWORD"] = "abacadaba12"

#conn = pg.connect(
#    host=os.environ["DB_HOST"],
#    port=os.environ["DB_PORT"],
#    dbname=os.environ["DB_NAME"],
#    user=os.environ["DB_USER"],
#    password=os.environ["DB_PASSWORD"]
#)

#"SELECT COUNT(*) AS quantidade_de_tabelas FROM information_schema.tables WHERE table_schema = 'perfil'"
df = pd.read_sql_query("SELECT table_name, COUNT(*) AS quantidade_de_atributos FROM information_schema.columns WHERE table_schema = 'perfil'GROUP BY table_name ORDER BY table_name;"
, con=cnx)
df


#%sql $engine.url
#%sql SELECT * FROM perfil.perfil_filiado WHERE sg_partido = 'UP'
#con = pg.connect(host='localhost', dbname= 'postgres', user='postgres', password= 'abacadaba12')

#query = 'SELECT * FROM perfil.perfil_filiado' 
#new_df = pd.read_sql(query, engine)
#new_df.head(3)
# Out:
#        table_name  quantidade_de_atributos
# 0  perfil_filiado                       21

# %%
#%reload_ext sql

cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
#engine = sqlalchemy.create_engine(cnx)


#os.environ["DB_HOST"] = "localhost"
#os.environ["DB_PORT"] = "5432"
#os.environ["DB_NAME"] = "Projeto"
#os.environ["DB_USER"] = "paugu"
#os.environ["DB_PASSWORD"] = "abacadaba12"

#conn = pg.connect(
#    host=os.environ["DB_HOST"],
#    port=os.environ["DB_PORT"],
#    dbname=os.environ["DB_NAME"],
#    user=os.environ["DB_USER"],
#    password=os.environ["DB_PASSWORD"]
#)

#"SELECT COUNT(*) AS quantidade_de_tabelas FROM information_schema.tables WHERE table_schema = 'perfil'"
df = pd.read_sql_query("SELECT table_name, COUNT(*) AS quantidade_de_atributos FROM information_schema.columns WHERE table_schema = 'delegados'GROUP BY table_name ORDER BY table_name;"
, con=cnx)
df


#%sql $engine.url
#%sql SELECT * FROM perfil.perfil_filiado WHERE sg_partido = 'UP'
#con = pg.connect(host='localhost', dbname= 'postgres', user='postgres', password= 'abacadaba12')

#query = 'SELECT * FROM perfil.perfil_filiado' 
#new_df = pd.read_sql(query, engine)
#new_df.head(3)
# Out:
#                            table_name  quantidade_de_atributos
# 0            delegado_partidario_agir                       14
# 1          delegado_partidario_avante                       14
# 2       delegado_partidario_cidadania                       14
# 3              delegado_partidario_dc                       14
# 4             delegado_partidario_dem                       14
# 5             delegado_partidario_mdb                       14
# 6            delegado_partidario_novo                       14
# 7        delegado_partidario_patriota                       14
# 8             delegado_partidario_pcb                       14
# 9           delegado_partidario_pcdob                       14
# 10            delegado_partidario_pco                       14
# 11            delegado_partidario_pdt                       14
# 12            delegado_partidario_phs                       14
# 13             delegado_partidario_pl                       14
# ...

# %%
#%reload_ext sql

cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
#engine = sqlalchemy.create_engine(cnx)


#os.environ["DB_HOST"] = "localhost"
#os.environ["DB_PORT"] = "5432"
#os.environ["DB_NAME"] = "Projeto"
#os.environ["DB_USER"] = "paugu"
#os.environ["DB_PASSWORD"] = "abacadaba12"

#conn = pg.connect(
#    host=os.environ["DB_HOST"],
#    port=os.environ["DB_PORT"],
#    dbname=os.environ["DB_NAME"],
#    user=os.environ["DB_USER"],
#    password=os.environ["DB_PASSWORD"]
#)

#"SELECT COUNT(*) AS quantidade_de_tabelas FROM information_schema.tables WHERE table_schema = 'perfil'"
df = pd.read_sql_query("SELECT table_name, COUNT(*) AS quantidade_de_atributos FROM information_schema.columns WHERE table_schema = 'orgaos'GROUP BY table_name ORDER BY table_name;"
, con=cnx)
df


#%sql $engine.url
#%sql SELECT * FROM perfil.perfil_filiado WHERE sg_partido = 'UP'
#con = pg.connect(host='localhost', dbname= 'postgres', user='postgres', password= 'abacadaba12')

#query = 'SELECT * FROM perfil.perfil_filiado' 
#new_df = pd.read_sql(query, engine)
#new_df.head(3)
# Out:
#                         table_name  quantidade_de_atributos
# 0            orgao_partidario_agir                       32
# 1          orgao_partidario_avante                       32
# 2       orgao_partidario_cidadania                       32
# 3              orgao_partidario_dc                       32
# 4             orgao_partidario_dem                       32
# 5             orgao_partidario_mdb                       32
# 6            orgao_partidario_novo                       32
# 7        orgao_partidario_patriota                       32
# 8             orgao_partidario_pcb                       32
# 9           orgao_partidario_pcdob                       32
# 10            orgao_partidario_pco                       32
# 11            orgao_partidario_pdt                       32
# 12            orgao_partidario_phs                       32
# 13             orgao_partidario_pl                       32
# 14            orgao_partidario_pmb                       32
# ...

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
SELECT relname AS "relation", pg_size_pretty(pg_total_relation_size(C.oid)) AS "total_size"
FROM pg_class C
LEFT JOIN pg_namespace N ON (N.oid = C.relnamespace)
WHERE nspname NOT IN ('pg_catalog', 'information_schema') AND C.relkind <> 'i' AND nspname !~ '^pg_toast'
ORDER BY pg_total_relation_size(C.oid) DESC;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#                     relation  total_size
# 0             perfil_filiado     2513 MB
# 1       orgao_partidario_mdb      184 MB
# 2      orgao_partidario_psdb      104 MB
# 3       orgao_partidario_pdt       95 MB
# 4        orgao_partidario_pt       93 MB
# ..                       ...         ...
# 70    delegado_partidario_up       16 kB
# 71   delegado_partidario_pmb       16 kB
# 72  delegado_partidario_novo       16 kB
# 73  delegado_partidario_rede       16 kB
# 74    orgao_partidario_uniao  8192 bytes
#
# [75 rows x 2 columns]

# %% [markdown]
# ### Definição das consultas
#
# Vamos exibir o resultado das consultas para retornar os dados do dataset.

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """

SELECT SQ_ORGAO_PARTIDARIO, SG_PARTIDO, NR_PARTIDO, NM_PARTIDO, CD_TIPO_ORGAO_PARTIDARIO, NM_TIPO_ORGAO_PARTIDARIO, CD_TIPO_ABRANGENCIA, DS_TIPO_ABRANGENCIA, DT_INICIO_VIGENCIA, DT_FIM_VIGENCIA, NM_SIT_ORGAO_PARTIDARIO, SG_UF, SG_UE, NM_UE, CD_MUNICIPIO, NM_MUNICIPIO, DS_ENDERECO_ORGAO, NR_CEP_ORGAO, NR_FONE_FIXO_ORGAO, NR_FONE_CEL_ORGAO, NR_FONE_COMERCIAL_ORGAO, NR_FAX_ORGAO, TX_EMAIL_ORGAO, SQ_CARGO_MEMBRO, DS_CARGO_MEMBRO, SQ_MEMBRO, NM_MEMBRO, DT_INICIO_EXERCICIO_MEMBRO, DT_FIM_EXERCICIO_MEMBRO, ST_MEMBRO FROM orgaos.orgao_partidario_PDT WHERE SG_PARTIDO = 'PDT' AND SG_UF = 'SP' ORDER BY NM_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#       sq_orgao_partidario sg_partido nr_partido  \
# 0                  199454        PDT         12
# 1                  199454        PDT         12
# 2                  199454        PDT         12
# 3                  199454        PDT         12
# 4                  199454        PDT         12
# ...                   ...        ...        ...
# 13837              382030        PDT         12
# 13838              382030        PDT         12
# 13839              382030        PDT         12
# 13840              382030        PDT         12
# 13841              382030        PDT         12
#
#                             nm_partido cd_tipo_orgao_partidario  \
# 0      PARTIDO DEMOCRÁTICO TRABALHISTA                      472
# 1      PARTIDO DEMOCRÁTICO TRABALHISTA                      472
# 2      PARTIDO DEMOCRÁTICO TRABALHISTA                      472
# 3      PARTIDO DEMOCRÁTICO TRABALHISTA                      472
# ...

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
        SELECT o.NM_PARTIDO, d.NM_DELEGADO
FROM orgaos.orgao_partidario_pt o
INNER JOIN delegados.delegado_partidario_pt d
ON o.SG_PARTIDO = d.SG_PARTIDO
WHERE o.NM_PARTIDO = 'PARTIDO DOS TRABALHADORES'
GROUP BY o.NM_PARTIDO,d.NM_DELEGADO 
ORDER BY o.NM_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#                     nm_partido                                nm_delegado
# 0    PARTIDO DOS TRABALHADORES                  Francisco de Assis Ávila
# 1    PARTIDO DOS TRABALHADORES                    ABDALA RIBEIRO DA SILVA
# 2    PARTIDO DOS TRABALHADORES                 Adailton Oliveira da Costa
# 3    PARTIDO DOS TRABALHADORES                               ADALTO PAIVA
# 4    PARTIDO DOS TRABALHADORES              ADEMARCOS MOREIRA DE OLIVEIRA
# ..                         ...                                        ...
# 300  PARTIDO DOS TRABALHADORES                   WASHIGTON DA SILVA LIMA
# 301  PARTIDO DOS TRABALHADORES                      WILLIAN CÉSAR SAMPAIO
# 302  PARTIDO DOS TRABALHADORES  WILSON GUILHERME CAETANO FONTANA DA SILVA
# 303  PARTIDO DOS TRABALHADORES                      WRIEL DA SILVA VIEIRA
# 304  PARTIDO DOS TRABALHADORES             ZELIA MARIA FORNAZIER OLIVEIRA
#
# [305 rows x 2 columns]

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
SELECT o.NM_PARTIDO, d.NM_DELEGADO
FROM orgaos.orgao_partidario_pt o
INNER JOIN delegados.delegado_partidario_pt d
ON o.SG_PARTIDO = d.SG_PARTIDO
WHERE o.NM_PARTIDO = 'UNIDADE POPULAR'
GROUP BY o.NM_PARTIDO,d.NM_DELEGADO
ORDER BY o.NM_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
# Empty DataFrame
# Columns: [nm_partido, nm_delegado]
# Index: []

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
SELECT o.NM_PARTIDO, d.NM_DELEGADO, o.DT_INICIO_VIGENCIA, o.DT_FIM_VIGENCIA
FROM orgaos.orgao_partidario_pt o
INNER JOIN delegados.delegado_partidario_pt d
ON o.SG_PARTIDO = d.SG_PARTIDO
WHERE o.SG_PARTIDO = 'PT'
GROUP BY o.NM_PARTIDO,d.NM_DELEGADO, o.DT_INICIO_VIGENCIA, o.DT_FIM_VIGENCIA
ORDER BY o.NM_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#                         nm_partido                                nm_delegado  \
# 0        PARTIDO DOS TRABALHADORES           LUIZ HENRIQUE BELLUCCI PETERLINI
# 1        PARTIDO DOS TRABALHADORES                       FERNANDA VIEIRA CRUZ
# 2        PARTIDO DOS TRABALHADORES                       FERNANDA VIEIRA CRUZ
# 3        PARTIDO DOS TRABALHADORES                     José Francisco Cândido
# 4        PARTIDO DOS TRABALHADORES                     ROSELI CORDEIRO EURICH
# ...                            ...                                        ...
# 1626255  PARTIDO DOS TRABALHADORES                     CAROLINE SOARES BORGES
# 1626256  PARTIDO DOS TRABALHADORES                         ANTÔNIO SEGAN CUBA
# 1626257  PARTIDO DOS TRABALHADORES                    AILTON GONÇALVES COSTA
# 1626258  PARTIDO DOS TRABALHADORES                EDIVALDO DE SOUZA MAGALHÃES
# 1626259  PARTIDO DOS TRABALHADORES  ana clara santana santos amorim gonçalves
#
# ...

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
SELECT o.NM_PARTIDO, d.NM_DELEGADO, o.NM_MEMBRO
FROM orgaos.orgao_partidario_pt o
INNER JOIN delegados.delegado_partidario_pt d
ON o.SG_PARTIDO = d.SG_PARTIDO
WHERE o.SG_PARTIDO = 'PT'
GROUP BY o.NM_PARTIDO,d.NM_DELEGADO, o.NM_MEMBRO
ORDER BY o.NM_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#                          nm_partido                     nm_delegado  \
# 0         PARTIDO DOS TRABALHADORES       Francisco de Assis Ávila
# 1         PARTIDO DOS TRABALHADORES       Francisco de Assis Ávila
# 2         PARTIDO DOS TRABALHADORES       Francisco de Assis Ávila
# 3         PARTIDO DOS TRABALHADORES       Francisco de Assis Ávila
# 4         PARTIDO DOS TRABALHADORES       Francisco de Assis Ávila
# ...                             ...                             ...
# 41346100  PARTIDO DOS TRABALHADORES  ZELIA MARIA FORNAZIER OLIVEIRA
# 41346101  PARTIDO DOS TRABALHADORES  ZELIA MARIA FORNAZIER OLIVEIRA
# 41346102  PARTIDO DOS TRABALHADORES  ZELIA MARIA FORNAZIER OLIVEIRA
# 41346103  PARTIDO DOS TRABALHADORES  ZELIA MARIA FORNAZIER OLIVEIRA
# 41346104  PARTIDO DOS TRABALHADORES  ZELIA MARIA FORNAZIER OLIVEIRA
#
#                                  nm_membro
# 0         -MARIA XAVIER BORGES DE OLIVEIRA
# 1                  ALBINO RIBEIRO DA ROCHA
# ...

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
SELECT o.NM_PARTIDO, d.NM_DELEGADO, o.NM_MUNICIPIO
FROM orgaos.orgao_partidario_pt o
INNER JOIN delegados.delegado_partidario_pt d
ON o.SG_PARTIDO = d.SG_PARTIDO
WHERE o.SG_PARTIDO = 'PT'
GROUP BY o.NM_PARTIDO,d.NM_DELEGADO, o.NM_MUNICIPIO
ORDER BY o.NM_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#                         nm_partido                    nm_delegado  \
# 0        PARTIDO DOS TRABALHADORES        BENILDO MARCIO DA SILVA
# 1        PARTIDO DOS TRABALHADORES            ADRIANO DE OLIVEIRA
# 2        PARTIDO DOS TRABALHADORES  LUIS VINICIUS DE ARAGAO COSTA
# 3        PARTIDO DOS TRABALHADORES      JOÃO ISRAEL PEREIRA PINTO
# 4        PARTIDO DOS TRABALHADORES    SERGIO RICARDO LIMA BEZERRA
# ...                            ...                            ...
# 1619545  PARTIDO DOS TRABALHADORES       RAIMUNDO CASTRO DE SOUZA
# 1619546  PARTIDO DOS TRABALHADORES     REGINALDO QUADROS OLIVEIRA
# 1619547  PARTIDO DOS TRABALHADORES  LUIZ CARLOS DE OLIVEIRA SILVA
# 1619548  PARTIDO DOS TRABALHADORES         juarez coleta de souza
# 1619549  PARTIDO DOS TRABALHADORES          IVÔNIO GASPAR BIZARRO
#
#                      nm_municipio
# 0                     DOM JOAQUIM
# 1                   SIMÃO PEREIRA
# 2           VISTA ALEGRE DO PRATA
# ...

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
SELECT d.SG_PARTIDO, d.NM_DELEGADO, p.qt_filiados
FROM delegados.delegado_partidario_pt d
INNER JOIN perfil.perfil_filiado p
ON d.SG_PARTIDO = p.SG_PARTIDO
WHERE d.SG_PARTIDO = 'PT'
GROUP BY d.SG_PARTIDO, d.NM_DELEGADO, p.qt_filiados
ORDER BY d.SG_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#       sg_partido                     nm_delegado  qt_filiados
# 0             PT      EVERALDO ANUNCIAÇÃO FARIAS           61
# 1             PT          SILVANIA LIMA OLIVEIRA          208
# 2             PT  GERALDO LOPES DA SILVA JUNIOR            66
# 3             PT        WASHIGTON DA SILVA LIMA            22
# 4             PT    SIMONE MAGALHAES CANVALCANTE           61
# ...          ...                             ...          ...
# 39950         PT         David Selhorst da Silva          125
# 39951         PT             JULIANA ALVES BRITO           17
# 39952         PT     cristiano tadeu da silveira           43
# 39953         PT       IZAQUE DAMASO DA SILVEIRA          102
# 39954         PT   NELSON LUIS BORGES DE BARROS            87
#
# [39955 rows x 3 columns]

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
SELECT d.SG_PARTIDO, d.NM_DELEGADO, p.NM_MUNICIPIO
FROM delegados.delegado_partidario_pt d
INNER JOIN perfil.perfil_filiado p
ON d.SG_PARTIDO = p.SG_PARTIDO
WHERE d.SG_PARTIDO = 'PT'
GROUP BY d.SG_PARTIDO, d.NM_DELEGADO, p.NM_MUNICIPIO
ORDER BY d.SG_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#         sg_partido                                nm_delegado  \
# 0               PT                  ODAIL MARQUES DE CARVALHO
# 1               PT                ROBERTO DIMAS GARCIA CORREA
# 2               PT                       JOSÉ OSMAR RODRIGUES
# 3               PT                  JANDIRA DE SOUZA OLIVEIRA
# 4               PT                          EVERALDO SALVADOR
# ...            ...                                        ...
# 1639065         PT  WILSON GUILHERME CAETANO FONTANA DA SILVA
# 1639066         PT                 OTHON DE SA FUNCHAL BARROS
# 1639067         PT                JOSE TADEU PEIXOTO DA COSTA
# 1639068         PT              ANTONIO CARLOS MOREIRA MORENO
# 1639069         PT                       JAMIR RODRIGUES ARCO
#
#                   nm_municipio
# 0                    RIO LARGO
# 1                  MÂNCIO LIMA
# 2        PRESIDENTE FIGUEIREDO
# 3                 DOIS RIACHOS
# 4        PRESIDENTE FIGUEIREDO
# ...

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
SELECT d.SG_PARTIDO, d.NM_DELEGADO, p.CD_OCUPACAO
FROM delegados.delegado_partidario_pt d
INNER JOIN perfil.perfil_filiado p
ON d.SG_PARTIDO = p.SG_PARTIDO
WHERE d.SG_PARTIDO = 'PT'
GROUP BY d.SG_PARTIDO, d.NM_DELEGADO, p.CD_OCUPACAO
ORDER BY d.SG_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#       sg_partido                          nm_delegado cd_ocupacao
# 0             PT                    EVERALDO SALVADOR         242
# 1             PT              ABDALA RIBEIRO DA SILVA          68
# 2             PT       LAURENÇO AGUIAR DO NASCIMENTO           53
# 3             PT  BIANCA ESTHEFANIE DE OLIVEIRA SOUZA         173
# 4             PT           OTHON DE SA FUNCHAL BARROS           2
# ...          ...                                  ...         ...
# 81430         PT            EDMILSON CARDOSO DA SILVA         116
# 81431         PT            RAIMUNDO RIBEIRO DA SILVA          29
# 81432         PT             LILIAN DA SILVA FERREIRA         159
# 81433         PT        LUIS VINICIUS DE ARAGÃO COSTA         122
# 81434         PT       LINDALVA SERRÃO E SILVA ARAGÃO         227
#
# [81435 rows x 3 columns]

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
SELECT d.SG_PARTIDO, d.NM_DELEGADO, p.CD_ESDAO_CIVIL
FROM delegados.delegado_partidario_pt d
INNER JOIN perfil.perfil_filiado p
ON d.SG_PARTIDO = p.SG_PARTIDO
WHERE d.SG_PARTIDO = 'PT'
GROUP BY d.SG_PARTIDO, d.NM_DELEGADO, p.CD_ESDAO_CIVIL
ORDER BY d.SG_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#      sg_partido                                nm_delegado cd_esdao_civil
# 0            PT                        ELSON DA SILVA GREB              3
# 1            PT              JOÃO CARLOS DE OLIVEIRA PIRAÍ              7
# 2            PT                               ADALTO PAIVA              1
# 3            PT                       ÉDIMAR LUIS DE SOUSA              3
# 4            PT  ana clara santana santos amorim gonçalves              7
# ...         ...                                        ...            ...
# 1825         PT             UEVERTON RODRIGO DE SOUZA DIAS              0
# 1826         PT             CARLOS EDUARDO DOURADO BASTOS               7
# 1827         PT                       JOSÉ OSMAR RODRIGUES              7
# 1828         PT                EDIVALDO DE SOUZA MAGALHÃES              7
# 1829         PT                   JULIO CESAR MAFRA AQUINO              5
#
# [1830 rows x 3 columns]

# %%
cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'

query = """
SELECT d.SG_PARTIDO, d.NM_DELEGADO, p.CD_GENERO
FROM delegados.delegado_partidario_pt d
INNER JOIN perfil.perfil_filiado p
ON d.SG_PARTIDO = p.SG_PARTIDO
WHERE d.SG_PARTIDO = 'PT'
GROUP BY d.SG_PARTIDO, d.NM_DELEGADO, p.CD_GENERO
ORDER BY d.SG_PARTIDO;
"""
df = pd.read_sql_query(query, con = cnx)

df
# Out:
#     sg_partido                             nm_delegado cd_genero
# 0           PT                    JOSE ANTONIO PEREIRA         0
# 1           PT       LUIZ EDUARDO RODRIGUES GREENHALGH         0
# 2           PT  Vitor Henrique Küster Moraes Maximiano         4
# 3           PT               ELIEZER DE SANTANA SANTOS         4
# 4           PT                    FERNANDA VIEIRA CRUZ         0
# ..         ...                                     ...       ...
# 910         PT                         IZELIA DA SILVA         0
# 911         PT             SERGIO RICARDO LIMA BEZERRA         2
# 912         PT                         CLECI LIVINALLI         2
# 913         PT                  IRINEU PEREIRA SANTOS          2
# 914         PT                           LUIS VOLOCHEN         4
#
# [915 rows x 3 columns]

# %% [markdown]
# ### Definição do Formulário do CRUD
#
# Os componentes são salvos em variáveis dos widgets. o campo value da variável acessa o valor que foi preenchido. Por exemplo, na célula abaixo é definido um componente pnome do tipo widgets.Text. O comando pnome.value vai acessar o valor que foi preenchido nessa caixa de texto. Isso serve para todos os componentes.

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''


nm_ue = widgets.Text(
    value = "",
    description='Nome da cidade ou estado do delegado: ',
    disabled=False
)



# botão com descrição 

button3 = widgets.Button(description="Consultar", value='')


        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        #query = f"select * from pessoa where ('{cpf.value}'='{flag}' or cpf='{cpf.value}') and ('{nome.value}'='{flag}' or nome like '{nome.value}%')" 
        query = f"select nm_delegado, sg_partido, ds_tipo_abrangencia from delegados.delegado_partidario_agir where nm_ue = '{nm_ue.value}'"
        cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
        df = pd.read_sql_query(query, con = cnx)
        output.clear_output()
        display(nm_ue, button3, df)
    except:
        output.clear_output()
        display(nm_ue, button3)
        display("Não foi possível realizar a consulta.")

# Definição de qual botão vai executar a ação
button3.on_click(on_button_clicked_query)

# Saída da tela
output = widgets.Output()

with output:
    output.clear_output()
    display(nm_ue, button3)

output
# Out:
# Output()

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''


nm_ue = widgets.Text(
    value = "",
    description='Nome da cidade ou estado do delegado: ',
    disabled=False
)



# botão com descrição 

button3 = widgets.Button(description="Consultar", value='')


        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        #query = f"select * from pessoa where ('{cpf.value}'='{flag}' or cpf='{cpf.value}') and ('{nome.value}'='{flag}' or nome like '{nome.value}%')" 
        query = f"select nm_delegado, sg_partido, ds_tipo_abrangencia from delegados.delegado_partidario_pt where nm_ue = '{nm_ue.value}'"
        cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
        df = pd.read_sql_query(query, con = cnx)
        output.clear_output()
        display(nm_ue, button3, df)
    except:
        output.clear_output()
        display(nm_ue, button3)
        display("Não foi possível realizar a consulta.")

# Definição de qual botão vai executar a ação
button3.on_click(on_button_clicked_query)

# Saída da tela
output = widgets.Output()

with output:
    output.clear_output()
    display(nm_ue, button3)

output
# Out:
# Output()

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''


nm_ue = widgets.Text(
    value = "",
    description='Nome da cidade ou estado do delegado: ',
    disabled=False
)



# botão com descrição 

button3 = widgets.Button(description="Consultar", value='')


        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        #query = f"select * from pessoa where ('{cpf.value}'='{flag}' or cpf='{cpf.value}') and ('{nome.value}'='{flag}' or nome like '{nome.value}%')" 
        query = f"select nm_delegado,sg_partido, ds_tipo_abrangencia from delegados.delegado_partidario_psdb where nm_ue = '{nm_ue.value}'"
        cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
        df = pd.read_sql_query(query, con = cnx)
        output.clear_output()
        display(nm_ue, button3, df)
    except:
        output.clear_output()
        display(nm_ue, button3)
        display("Não foi possível realizar a consulta.")

# Definição de qual botão vai executar a ação
button3.on_click(on_button_clicked_query)

# Saída da tela
output = widgets.Output()

with output:
    output.clear_output()
    display(nm_ue, button3)

output
# Out:
# Output()

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''


nm_ue = widgets.Text(
    value = "",
    description='Nome da cidade ou estado do delegado: ',
    disabled=False
)



# botão com descrição 

button3 = widgets.Button(description="Consultar", value='')


        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        #query = f"select * from pessoa where ('{cpf.value}'='{flag}' or cpf='{cpf.value}') and ('{nome.value}'='{flag}' or nome like '{nome.value}%')" 
        query = f"select nm_delegado,sg_partido, ds_tipo_abrangencia from delegados.delegado_partidario_up where nm_ue = '{nm_ue.value}'"
        cnx = 'postgresql://postgres:abacadaba12@localhost/Projeto'
        df = pd.read_sql_query(query, con = cnx)
        output.clear_output()
        display(nm_ue, button3, df)
    except:
        output.clear_output()
        display(nm_ue, button3)
        display("Não foi possível realizar a consulta.")

# Definição de qual botão vai executar a ação
button3.on_click(on_button_clicked_query)

# Saída da tela
output = widgets.Output()

with output:
    output.clear_output()
    display(nm_ue, button3)

output
# Out:
# Output()
